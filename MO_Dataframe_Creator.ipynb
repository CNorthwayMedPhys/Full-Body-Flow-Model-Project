# %%
import pandas as pd

# %%
data = [['Ascending aorta I', 2, [1.25,1.23], [1,2]],
    ['Coronorary', 10,[0.3,0.3],'ST'],
    ['Ascending Aorta II', 5, [1.23, 1.14],[3,4]],
     ['Anonyma', 3.5, [.7,.7], [5,6]],
    ['Aortic Arch I', 1.8,[1.14,1.11],[7,8]],
 ['R Subclavian', 42,[0.44,0.28],'ST'],
         ['R Common Carotid', 17,[0.29,0.28],'ST'],
        ['L Common Carotid', 19,[0.29,0.28],'ST'],
         ['Aortic Arch II', 1,[1.11,1.09],[9,10]],
         ['L Subclavian', 43,[0.44,0.28],'ST'],
         ['Thoracic Aorta',18.8,[1.09,0.85],[11,12]],
         ['Celiac Axis',3,[0.33,0.3],'ST'],
         ['Abdominal Aorta I',2,[0.85,0.83],[13,14]],
         ['Superior Mesenteric',5,[0.33,0.33],'ST'],
     ['Abdominal Aorta II', 2,[0.83,0.8],[15,16]],
         ['R Renal',3,[0.28,0.25],'ST'],
         ['Abdominal Aorta III',1,[0.8,0.79],[17,18]],
         ['L Renal',3,[0.28,0.25],'ST'],
         ['Abdominal Aorta IV',6,[0.79,0.73],[19,20]],
         ['Inferior Mesenteric',4,[0.2,0.18],'ST'],
         ['Abdominal Aorta V',3,[0.73,0.7],[21,22]],
         ['R External Iliac',6.5,[0.45,0.43],[23,24]],
     ['L External Iliac',6.5,[0.45,0.43],[25,26]],
         ['R Femoral I',13,[0.43,0.4],[27,28]],
         ['R Internal Iliac',4.5,[0.2,0.2],'ST'],
         ['L Femoral I',13,[0.43,0.4],[29,30]],
         ['L Internal Iliac',4.5,[0.2,0.2],'ST'],
         ['R Femoral II',44,[0.4,0.3],'ST'],
         ['R Deep Femoral',11,[0.2,0.2],'ST'],
         ['L Femoral II',44,[0.4,0.3],'ST'],
         ['L Deep Femoral',11,[0.2,0.2],'ST']]

# %%
df= pd.DataFrame(data,columns=['Name','L','Radius Values','End Condition'])
df.to_pickle('MOArray_Coronary.pkl')

# %%
display(df)
# Out:
#                    Name     L Radius Values End Condition
# 0     Ascending aorta I   2.0  [1.25, 1.23]        [1, 2]
# 1            Coronorary  10.0    [0.3, 0.3]            ST
# 2    Ascending Aorta II   5.0  [1.23, 1.14]        [3, 4]
# 3               Anonyma   3.5    [0.7, 0.7]        [5, 6]
# 4         Aortic Arch I   1.8  [1.14, 1.11]        [7, 8]
# 5          R Subclavian  42.0  [0.44, 0.28]            ST
# 6      R Common Carotid  17.0  [0.29, 0.28]            ST
# 7      L Common Carotid  19.0  [0.29, 0.28]            ST
# 8        Aortic Arch II   1.0  [1.11, 1.09]       [9, 10]
# 9          L Subclavian  43.0  [0.44, 0.28]            ST
# 10       Thoracic Aorta  18.8  [1.09, 0.85]      [11, 12]
# 11          Celiac Axis   3.0   [0.33, 0.3]            ST
# 12    Abdominal Aorta I   2.0  [0.85, 0.83]      [13, 14]
# 13  Superior Mesenteric   5.0  [0.33, 0.33]            ST
# 14   Abdominal Aorta II   2.0   [0.83, 0.8]      [15, 16]
# ...
