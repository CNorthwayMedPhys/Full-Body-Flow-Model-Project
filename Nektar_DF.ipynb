# %%
import pandas as pd

# %%
data = [['Ascending aorta', 5.8, [1.54,1.5], [1,2]],
        ['Aortic Arch A', 2.3, [1.32, 1.26],[13,14]],
        ['Brachiocephalic', 3.9, [1.06,0.94], [3,4]],
        ['R subclavian', 3.9,[0.6,0.47],[5,6]],
        ['R common carotid', 10.8,[0.57,0.29],[11,12]],
        ['R vertebral', 17.1,[0.19,0.14],'ST'],
        ['R brachial', 48.5,[0.42,0.24],[7,8]],
        ['R radial', 27,[0.19,0.16],'ST'],
        ['R ulnar A', 7.7,[0.19,0.17],[9,10]],
        ['R interosseous', 9.1,[0.11,0.09],'ST'],
        ['R ulnar B', 19.7,[0.16,0.14],'ST'],
        ['R internal carotid', 20.5, [0.29,0.22],'ST'],
        ['R external carotid', 18.7,[0.13,0.08],'ST'],
        ['Aortic Arch B', 4.5,[1.12,1.09],[17,18]],
       ['L. common carotid', 16,[0.51,0.25],[15,16]],
       ['L. internal carotid', 20.5,[0.22,0.17],'ST'],
       ['L. external carotid', 18.7,[0.1,0.06],'ST'],
       ['Thoracic aorta A', 6,[1.04,0.99],[25,26]],
       ['L. subclavian', 3.9,[0.57,0.44],[19,20]],
       ['L. vertebral', 17,[1.04,0.99],'ST'],
       ['L. brachial', 48.5,[0.42,0.24],[21,22]],
        ['L. radial', 27, [0.86,0.67],'ST'],
       ['L. ulnar A', 7.7,[0.22,0.22],[23,24]],
       ['L. interosseous', 9.1,[0.09,0.09],'ST'],
       ['L. ulnar B', 19.7,[0.21,0.19],'ST'],
       ['Intercostals',9.2,[0.66,0.49],'ST'],
       ['Thoracic aorta B', 12,[0.86,0.67],[27,28]],
       ['Abdominal aorta A', 6.1,[0.63,0.63],[33,34]],
       ['Celiac A', 2.3,[0.41,0.36],[29,30]],
       ['Celiac B', 2.3,[0.27,0.25],[31,32]],
       ['Hepatic', 7.6,[0.28,0.23],'ST'],
       ['Gastric', 8.2,[0.16,0.15],'ST'],
       ['Splenic', 7.2,[0.22,0.2],'ST'],
       ['Superior mesenteric', 6.8,[0.41,0.37],'ST'],
       ['Abdominal aorta B', 2.3,[0.6,0.59],[35,36]],
       ['L renal', 3.7,[0.27,0.27],'ST'],
       ['Abdominal aorta C', 2.3,[0.61,0.61],[37,38]],
       ['R renal', 3.7,[0.27,0.27],'ST'],
       ['Abdominal aorta D', 12.2,[0.6,0.57],[39,40]],
       ['Inferior mesenteric', 5.8,[0.24,0.16],'ST'],
       ['Abdominal aorta E', 2.3,[0.56,0.54],[41,42]],
       ['L. common iliac', 6.8,[0.41,0.36],[43,44]],
       ['R. common iliac', 6.8,[0.41,0.36],[49,50]],
       ['L. external iliac', 16.6,[0.33,0.31],[45,46]],
       ['L. internal iliac', 5.8,[0.21,0.21],'ST'],
       ['L.femoral', 50.9,[0.27,0.19],[47,48]],
       ['L. deep femoral', 14.5,[0.21,0.19],'ST'],
       ['L. posterior tibial', 36.9,[0.13,0.11],'ST'],
       ['L. anterior tibial', 39.8,[0.13,0.11],'ST'],
       ['R. external iliac', 16.6,[0.33,0.31],[51,52]],
       ['R. internal iliac', 5.8,[0.21,0.21],'ST'],
       ['R.femoral', 50.9,[0.27,0.19],[53,54]],
       ['R. deep femoral', 14.5,[0.21,0.19],'ST'],
       ['R. posterior tibial', 36.9,[0.13,0.11],'ST'],
       ['R. anterior tibial', 39.8,[0.13,0.11],'ST']]

# %%
df= pd.DataFrame(data,columns=['Name','L','Radius Values','End Condition'])
df.to_pickle('Nektar_array.pkl')

# %%
display(df)
# Out:
#                    Name     L Radius Values End Condition
# 0       Ascending aorta   5.8   [1.54, 1.5]        [1, 2]
# 1         Aortic Arch A   2.3  [1.32, 1.26]      [13, 14]
# 2       Brachiocephalic   3.9  [1.06, 0.94]        [3, 4]
# 3          R subclavian   3.9   [0.6, 0.47]        [5, 6]
# 4      R common carotid  10.8  [0.57, 0.29]      [11, 12]
# 5           R vertebral  17.1  [0.19, 0.14]            ST
# 6            R brachial  48.5  [0.42, 0.24]        [7, 8]
# 7              R radial  27.0  [0.19, 0.16]            ST
# 8             R ulnar A   7.7  [0.19, 0.17]       [9, 10]
# 9        R interosseous   9.1  [0.11, 0.09]            ST
# 10            R ulnar B  19.7  [0.16, 0.14]            ST
# 11   R internal carotid  20.5  [0.29, 0.22]            ST
# 12   R external carotid  18.7  [0.13, 0.08]            ST
# 13        Aortic Arch B   4.5  [1.12, 1.09]      [17, 18]
# 14    L. common carotid  16.0  [0.51, 0.25]      [15, 16]
# ...
