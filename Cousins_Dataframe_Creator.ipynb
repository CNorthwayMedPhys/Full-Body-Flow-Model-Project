# %%
import pandas as pd

# %%
#Create the list based on Cousins_2014 with format: Name, lam, Radius Values, End Condition

data = [['Ascending aorta', 5.6, [12.5,11.4], [1,2]],
     ['Anonyma', 5, [7,7], [3,4]],
     ['Aortic Arch I', 1.58,[11.4,11.1],[5,6]],
     ['R Subclavian', 7.73,[4.4,4.3],[7,8]],
     ['R Common Carotid', 58.62,[2.9,2.8],'ST'],
     ['L Common Carotid', 65.52,[2.9,2.8],'ST'],
     ['Aortic Arch II', 0.9,[11.1,10.9],[9,10]],
     ['R Brachial', 94.42,[4.3,2.8],[11,12]],
     ['R Vertebral', 105.71,[1.4,1.4],'ST'],
     ['L Subclavian', 7.73,[4.4,4.3],[13,14]],
     ['Thoracic Aorta',17.25,[10.9,8.5],[15,16]],
     ['R Radial',138.24,[1.7,1.4],'ST'],
     ['R Ulnar',30.45,[2.2,2.2],'ST'],
     ['L Vertebral', 105.71,[1.4,1.4],'ST'],
     ['L Brachial', 94.42,[4.3,2.8],[17,18]],
     ['Celiac Axis',9.09,[3.3,3],'ST'],
     ['Abdominal Aorta I',2.35,[8.5,8.3],[19,20]],
     ['L Ulnar',30.45,[2.2,2.2],'ST'],
     ['L Radial',138.24,[1.7,1.4],'ST'],
     ['Superior Mesenteric',16.67,[3.3,3.3],'ST'],
     ['Abdominal Aorta II', 2.41,[8.3,8],[21,22]],
     ['R Renal',10.71,[2.8,2.5],'ST'],
     ['Abdominal Aorta III',1.25,[8,7.9],[23,24]],
     ['L Renal',10.71,[2.8,2.5],'ST'],
     ['Abdominal Aorta IV',7.59,[7.9,7.3],[25,26]],
     ['Inferior Mesenteric',20,[2,1.8],'ST'],
     ['Abdominal Aorta V',4.11,[7.3,7],[27,28]],
     ['R External Iliac',14.44,[4.5,4.5],[29,30]],
     ['L External Iliac',14.44,[4.5,4.5],[31,32]],
     ['R Femoral I',32.5,[4.3,4],[33,34]],
     ['R Internal Iliac',22.5,[2,2],'ST'],
     ['L Femoral I',32.5,[4.3,4],[35,36]],
     ['L Internal Iliac',22.5,[2,2],'ST'],
     ['R Femoral II',110,[4,3],'ST'],
     ['R Deep Femoral',55,[2,2],'ST'],
     ['L Femoral II',110,[4,3],'ST'],
     ['L Deep Femoral',55,[2,2],'ST']]

# %%
df= pd.DataFrame(data,columns=['Name','lam','Radius Values','End Condition'])
df.to_pickle('CousinsArray.pkl')

# %%
display(df)
# Out:
#                    Name     lam Radius Values End Condition
# 0       Ascending aorta    5.60  [12.5, 11.4]        [1, 2]
# 1               Anonyma    5.00        [7, 7]        [3, 4]
# 2         Aortic Arch I    1.58  [11.4, 11.1]        [5, 6]
# 3          R Subclavian    7.73    [4.4, 4.3]        [7, 8]
# 4      R Common Carotid   58.62    [2.9, 2.8]            ST
# 5      L Common Carotid   65.52    [2.9, 2.8]            ST
# 6        Aortic Arch II    0.90  [11.1, 10.9]       [9, 10]
# 7            R Brachial   94.42    [4.3, 2.8]      [11, 12]
# 8           R Vertebral  105.71    [1.4, 1.4]            ST
# 9          L Subclavian    7.73    [4.4, 4.3]      [13, 14]
# 10       Thoracic Aorta   17.25   [10.9, 8.5]      [15, 16]
# 11             R Radial  138.24    [1.7, 1.4]            ST
# 12              R Ulnar   30.45    [2.2, 2.2]            ST
# 13          L Vertebral  105.71    [1.4, 1.4]            ST
# 14           L Brachial   94.42    [4.3, 2.8]      [17, 18]
# ...
