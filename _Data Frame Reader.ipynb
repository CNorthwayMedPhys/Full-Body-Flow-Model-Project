# %%
import pandas as pd
import tkinter
from tkinter import filedialog
import numpy as np
tkinter.Tk().withdraw() # prevents an empty tkinter window from appearing
file_name = filedialog.askopenfilename()

df = pd.read_pickle(file_name)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
display(df)
#pd.reset_option('all')
# Out:
#                    Name     L Radius Values End Condition
# 0     Ascending aorta I   2.0  [1.25, 1.23]        [1, 2]
# 1            Coronorary  10.0    [0.3, 0.3]            ST
# 2    Ascending Aorta II   5.0  [1.23, 1.14]        [3, 4]
# 3               Anonyma   3.5    [0.7, 0.7]        [5, 6]
# 4         Aortic Arch I   1.8  [1.14, 1.11]        [7, 8]
# 5          R Subclavian   3.4  [0.44, 0.43]       [9, 10]
# 6      R Common Carotid  17.0  [0.29, 0.28]            ST
# 7      L Common Carotid  19.0  [0.29, 0.28]            ST
# 8        Aortic Arch II   1.0  [1.11, 1.09]      [11, 12]
# 9            R Brachial  40.6  [0.43, 0.28]      [13, 14]
# 10          R Vertebral  14.8  [0.14, 0.14]            ST
# 11         L Subclavian   3.4  [0.44, 0.43]      [15, 16]
# 12       Thoracic Aorta  18.8  [1.09, 0.85]      [17, 18]
# 13             R Radial  23.5  [0.17, 0.14]            ST
# 14              R Ulnar   6.7  [0.22, 0.22]            ST
# 15          L Vertebral  14.8  [0.14, 0.14]            ST
# 16           L Brachial  40.6  [0.43, 0.28]      [19, 20]
# 17          Celiac Axis   3.0   [0.33, 0.3]            ST
# 18    Abdominal Aorta I   2.0  [0.85, 0.83]      [21, 22]
# 19              L Ulnar   6.7  [0.22, 0.22]            ST
# 20             L Radial  23.5  [0.17, 0.14]            ST
# 21  Superior Mesenteric   5.0  [0.33, 0.33]            ST
# 22   Abdominal Aorta II   2.0   [0.83, 0.8]      [23, 24]
# 23              R Renal   3.0  [0.28, 0.25]            ST
# 24  Abdominal Aorta III   1.0   [0.8, 0.79]      [25, 26]
# 25              L Renal   3.0  [0.28, 0.25]            ST
# 26   Abdominal Aorta IV   6.0  [0.79, 0.73]      [27, 28]
# 27  Inferior Mesenteric   4.0   [0.2, 0.18]            ST
# 28    Abdominal Aorta V   3.0   [0.73, 0.7]      [29, 30]
# 29     R External Iliac   6.5  [0.45, 0.43]      [31, 32]
# 30     L External Iliac   6.5  [0.45, 0.43]      [33, 34]
# 31          R Femoral I  13.0   [0.43, 0.4]      [35, 36]
# 32     R Internal Iliac   4.5    [0.2, 0.2]            ST
# 33          L Femoral I  13.0   [0.43, 0.4]      [37, 38]
# 34     L Internal Iliac   4.5    [0.2, 0.2]            ST
# 35         R Femoral II  44.0    [0.4, 0.3]            ST
# 36       R Deep Femoral  11.0    [0.2, 0.2]            ST
# 37         L Femoral II  44.0    [0.4, 0.3]            ST
# 38       L Deep Femoral  11.0    [0.2, 0.2]            ST

# %%
length = []


for i in range(0, np.shape(df)[0]):
    lam = df.at[i,'lam']
    Ru = df.at[i, 'Radius Values'][0]
    L = lam * Ru
    length=np.append(length, L )

df.insert(2, "Length", length, True)

# %%
length_df = df.sort_values(by=['Length'])
display(df)
# Out:
#                    Name     lam   Length Radius Values End Condition
# 0     Ascending aorta I    1.60   20.000  [12.5, 12.3]        [1, 2]
# 1            Coronorary   28.57   99.995      [3.5, 3]            ST
# 2    Ascending Aorta II    4.07   50.061  [12.3, 11.4]        [3, 4]
# 3               Anonyma    5.00   35.000        [7, 7]        [5, 6]
# 4         Aortic Arch I    1.58   18.012  [11.4, 11.1]        [7, 8]
# 5          R Subclavian    7.73   34.012    [4.4, 4.3]       [9, 10]
# 6      R Common Carotid   58.62  169.998    [2.9, 2.8]            ST
# 7      L Common Carotid   65.52  190.008    [2.9, 2.8]            ST
# 8        Aortic Arch II    0.90    9.990  [11.1, 10.9]      [11, 12]
# 9            R Brachial   94.42  406.006    [4.3, 2.8]      [13, 14]
# 10          R Vertebral  105.71  147.994    [1.4, 1.4]            ST
# 11         L Subclavian    7.73   34.012    [4.4, 4.3]      [15, 16]
# 12       Thoracic Aorta   17.25  188.025   [10.9, 8.5]      [17, 18]
# 13             R Radial  138.24  235.008    [1.7, 1.4]            ST
# 14              R Ulnar   30.45   66.990    [2.2, 2.2]            ST
# 15          L Vertebral  105.71  147.994    [1.4, 1.4]            ST
# 16           L Brachial   94.42  406.006    [4.3, 2.8]      [19, 20]
# 17          Celiac Axis    9.09   29.997      [3.3, 3]            ST
# 18    Abdominal Aorta I    2.35   19.975    [8.5, 8.3]      [21, 22]
# 19              L Ulnar   30.45   66.990    [2.2, 2.2]            ST
# 20             L Radial  138.24  235.008    [1.7, 1.4]            ST
# 21  Superior Mesenteric   16.67   55.011    [3.3, 3.3]            ST
# 22   Abdominal Aorta II    2.41   20.003      [8.3, 8]      [23, 24]
# 23              R Renal   10.71   29.988    [2.8, 2.5]            ST
# 24  Abdominal Aorta III    1.25   10.000      [8, 7.9]      [25, 26]
# 25              L Renal   10.71   29.988    [2.8, 2.5]            ST
# 26   Abdominal Aorta IV    7.59   59.961    [7.9, 7.3]      [27, 28]
# 27  Inferior Mesenteric   20.00   40.000      [2, 1.8]            ST
# 28    Abdominal Aorta V    4.11   30.003      [7.3, 7]      [29, 30]
# 29     R External Iliac   14.44   64.980    [4.5, 4.5]      [31, 32]
# 30     L External Iliac   14.44   64.980    [4.5, 4.5]      [33, 34]
# 31          R Femoral I   32.50  139.750      [4.3, 4]      [35, 36]
# 32     R Internal Iliac   22.50   45.000        [2, 2]            ST
# 33          L Femoral I   32.50  139.750      [4.3, 4]      [37, 38]
# 34     L Internal Iliac   22.50   45.000        [2, 2]            ST
# 35         R Femoral II  110.00  440.000        [4, 3]            ST
# 36       R Deep Femoral   55.00  110.000        [2, 2]            ST
# 37         L Femoral II  110.00  440.000        [4, 3]            ST
# 38       L Deep Femoral   55.00  110.000        [2, 2]            ST
