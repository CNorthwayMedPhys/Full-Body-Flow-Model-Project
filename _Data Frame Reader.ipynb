# %%
import pandas as pd
import tkinter
from tkinter import filedialog
import numpy as np
tkinter.Tk().withdraw() # prevents an empty tkinter window from appearing
file_name = filedialog.askopenfilename()

df = pd.read_pickle(file_name)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
display(df)
#pd.reset_option('all')
# Out:
#                    Name     Length End Condition
# 0          dias_aorta_0   7.504726        [1, 2]
# 1          dias_aorta_1   0.675013        [3, 4]
# 2          arteries11_0   6.720888        [5, 6]
# 3          dias_aorta_2   0.841416        [7, 8]
# 4           arteries2_0  21.878078            ST
# 5          arteries11_1  44.624413       [9, 10]
# 6          arteries37_0  18.967297            ST
# 7          dias_aorta_3  24.121654      [11, 12]
# 8           arteries5_0   3.786255      [13, 14]
# 9     arteries_rarm10_1   21.95004            ST
# 10     arteries_rarm2_0   2.966708      [15, 16]
# 11         dias_aorta_4    1.27815      [17, 18]
# 12          arteries0_0    1.18895      [19, 20]
# 13          arteries5_1  44.194015      [21, 22]
# 14         arteries41_0  19.714904            ST
# 15     arteries_rarm2_1  40.161626            ST
# 16    arteries_rarm13_0  12.563988            ST
# 17         dias_aorta_5   0.942314      [23, 24]
# 18          arteries1_0  21.618675            ST
# 19          arteries0_1   0.184477      [25, 26]
# 20         arteries42_0    5.64061            ST
# 21     arteries_larm2_1  25.212006            ST
# 22    arteries_larm10_0   2.717999      [27, 28]
# 23         dias_aorta_6   0.338908      [29, 30]
# 24  rkidney_arteries6_0  10.189378            ST
# 25          arteries0_2   10.03474            ST
# 26          arteries4_0   5.549735            ST
# 27    arteries_larm10_1  39.403293            ST
# 28    arteries_larm12_0  11.338882            ST
# 29         dias_aorta_7   6.309669      [31, 32]
# 30  lkidney_arteries0_0   8.648277            ST
# 31         dias_aorta_8   3.578662      [33, 34]
# 32         arteries24_0  15.536246            ST
# 33          arteries9_0   6.230391      [35, 36]
# 34         arteries27_0   6.415608      [37, 38]
# 35          arteries9_1   5.558768            ST
# 36    arteries_lleg22_0  13.720567      [39, 40]
# 37         arteries27_1  13.527127            ST
# 38    arteries_rleg18_0  11.958754      [41, 42]
# 39    arteries_lleg22_1  52.988749      [43, 44]
# 40     arteries_lleg6_0    9.75403            ST
# 41    arteries_rleg18_1   52.87848      [45, 46]
# 42     arteries_rleg1_0   9.612582            ST
# 43    arteries_lleg22_2  64.057795            ST
# 44    arteries_lleg17_0  53.100496            ST
# 45    arteries_rleg18_2   64.09709            ST
# 46    arteries_rleg23_0  53.245036            ST

# %%
length = []


for i in range(0, np.shape(df)[0]):
    lam = df.at[i,'lam']
    Ru = df.at[i, 'Radius Values'][0]
    L = lam * Ru / 10
    length=np.append(length, L )

df.insert(2, "Length", length, True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       1 length = []
#       4 for i in range(0, np.shape(df)[0]):
# ----> 5     lam = df.at[i,'lam']
#       6     Ru = df.at[i, 'Radius Values'][0]
#       7     L = lam * Ru / 10
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:2419, in _AtIndexer.__getitem__(self, key)
#    2416         raise ValueError("Invalid call for scalar access (getting)!")
#    2417     return self.obj.loc[key]
# -> 2419 return super().__getitem__(key)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:2371, in _ScalarAccessIndexer.__getitem__(self, key)
#    2368         raise ValueError("Invalid call for scalar access (getting)!")
#    2370 key = self._convert_key(key)
# -> 2371 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3870, in DataFrame._get_value(self, index, col, takeable)
#    3867     series = self._ixs(col, axis=1)
#    3868     return series._values[index]
# -> 3870 series = self._get_item_cache(col)
#    3871 engine = self.index._engine
#    3873 if not isinstance(self.index, MultiIndex):
#    3874     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3875     #  results if our categories are integers that dont match our codes
#    3876     # IntervalIndex: IntervalTree has no get_loc
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4255, in DataFrame._get_item_cache(self, item)
#    4250 res = cache.get(item)
#    4251 if res is None:
#    4252     # All places that call _get_item_cache have unique columns,
#    4253     #  pending resolution of GH#33047
# -> 4255     loc = self.columns.get_loc(item)
#    4256     res = self._ixs(loc, axis=1)
#    4258     cache[item] = res
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'lam'

# %%
length_df = df.sort_values(by=['Length'])
display(df)
