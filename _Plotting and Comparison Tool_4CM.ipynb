# %% [markdown]
# ## For the purpose of my 2024-Sept Committee Meeting
# I want to plot the results for both methods 3wk and ST on the same plot and then and the difference between them also plotted onthe same graph. I will do a proximal and distal plot.

# %%
import numpy as np
import tkinter
from tkinter import filedialog
from scipy import interpolate
import matplotlib.pyplot as plt

T = 0.914
tc = 4
tf = T*tc

# %%
#Import file

tkinter.Tk().withdraw() # prevents an empty tkinter window from appearing
file_name = filedialog.askopenfilename()

# %%
U = np.loadtxt(file_name, delimiter=',')

L= U.shape[0]
t = np.linspace(tf-T, tf, U.shape[1])
x = np.linspace(0,L,U.shape[0])
g = interpolate.interp2d(t, x, U, kind='linear')
    
x = np.linspace(0, L, len(t))
U = g(t, x)
    
WIDTH = 510  # the number latex spits out
FACTOR = 1.0  # the fraction of the width you'd like the figure to occupy
fig_width_pt  = WIDTH * FACTOR
inches_per_pt = 1.0 / 72.27
golden_ratio  = (np.sqrt(5) - 1.0) / 2.0  # because it looks good
fig_width_in  = fig_width_pt * inches_per_pt  # figure width in inches
fig_height_in = fig_width_in * golden_ratio   # figure height in inches
fig_dims    = [fig_width_in, fig_height_in] # fig dims as a list
    
nt = len(t)
x = np.linspace(0, L, nt)
Y, X = np.meshgrid(x, t)
pt = U.shape[0]
dz = int(pt/nt)
Z_1 = U[0:pt:dz,:]


plt.figure(figsize=fig_dims)
plt.plot( X, Z_1[:,0], label = "Proximal", c = 'darkorchid', ls = 'dotted')
plt.plot(X, Z_1[:,-1], label = "Distal", c= 'darkorchid')

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())


plt.title(file_name)
plt.xlabel('t (s)')
plt.ylabel('flow rate (cm^3/s)')
plt.xlim([min(t), max(t)])


#fname = "%s/%s/%s_q3d%d.png" % (plot_dir, suffix, suffix, pos)
#ig.savefig(fname, dpi=600, bbox_inches='tight')
# Out:
# C:\Users\cbnor\AppData\Local\Temp\ipykernel_29968\1726618748.py:6: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://gist.github.com/ev-br/8544371b40f414b7eaf3fe6217209bff`
#
#   g = interpolate.interp2d(t, x, U, kind='linear')
# C:\Users\cbnor\AppData\Local\Temp\ipykernel_29968\1726618748.py:9: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
# ...

# %%
#Import file

tkinter.Tk().withdraw() # prevents an empty tkinter window from appearing
file_name = filedialog.askopenfilename()

# %%
U = np.loadtxt(file_name, delimiter=',')

L= U.shape[0]
t = np.linspace(tf-T, tf, U.shape[1])
x = np.linspace(0,L,U.shape[0])
g = interpolate.interp2d(t, x, U, kind='linear')
    
x = np.linspace(0, L, len(t))
U = g(t, x)
    
WIDTH = 510  # the number latex spits out
FACTOR = 1.0  # the fraction of the width you'd like the figure to occupy
fig_width_pt  = WIDTH * FACTOR
inches_per_pt = 1.0 / 72.27
golden_ratio  = (np.sqrt(5) - 1.0) / 2.0  # because it looks good
fig_width_in  = fig_width_pt * inches_per_pt  # figure width in inches
fig_height_in = fig_width_in * golden_ratio   # figure height in inches
fig_dims    = [fig_width_in, fig_height_in] # fig dims as a list
    
nt = len(t)
x = np.linspace(0, L, nt)
Y, X = np.meshgrid(x, t)
pt = U.shape[0]
dz = int(pt/nt)
Z_2 = U[0:pt:dz,:]


plt.figure(figsize=fig_dims)
plt.plot( X, Z_2[:,0], label = "Proximal", c = 'darkorchid', ls = 'dotted')
plt.plot(X, Z_2[:,-1], label = "Distal", c= 'darkorchid')

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())


plt.title(file_name)
plt.xlabel('t (s)')
plt.ylabel('flow rate (cm^3/s)')
plt.xlim([min(t), max(t)])
# Out:
# C:\Users\cbnor\AppData\Local\Temp\ipykernel_29968\2022070537.py:6: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://gist.github.com/ev-br/8544371b40f414b7eaf3fe6217209bff`
#
#   g = interpolate.interp2d(t, x, U, kind='linear')
# C:\Users\cbnor\AppData\Local\Temp\ipykernel_29968\2022070537.py:9: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
# ...

# %%
Z = Z_2-Z_1

plt.figure(figsize=fig_dims)
plt.plot( X, Z_1[:,0], label = "3WK", c = 'black', ls = 'dotted')
plt.plot(X, Z_2[:,0], label = "ST", c= 'black')

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())


plt.title('Proximal')
plt.xlabel('t (s)')
plt.ylabel('flow rate (cm^3/s)')
plt.xlim([min(t), max(t)])
# Out:
# (2.742, 3.656)

# %%
Z = Z_2-Z_1

plt.figure(figsize=fig_dims)
plt.plot( X, Z_1[:,-1], label = "3WK", c = 'black', ls = 'dotted')
plt.plot(X, Z_2[:,-1], label = "ST", c= 'black')

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())


plt.title('Distal')
plt.xlabel('t (s)')
plt.ylabel('flow rate (cm^3/s)')
plt.xlim([min(t), max(t)])
# Out:
# (2.742, 3.656)

# %%
print(np.max(np.abs(Z[:,0])))
# Out:
# 0.19709003033843597

# %%
print(np.max(np.abs(Z[:,-1])))
# Out:
# 0.19384028270882725
