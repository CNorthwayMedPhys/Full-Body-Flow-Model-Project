# %%
import os
import numpy as np
import pandas as pd

path = os.getcwd()

# %%
#Load in dictionary of arteries

vessel_df = pd.read_pickle ('./SysArteries.pkl')
display(vessel_df)
# Out:
#                              Name         lam  \
# 0                         aorta_0    6.003781
# 1                         aorta_1        1.59
# 2       right_subclavian_artery_0         5.0
# 3                         aorta_2    0.758033
# 4    left_common_cartoid_artery_0  104.527284
# ..                            ...         ...
# 338             arteries_rleg28_0  139.086316
# 339             arteries_lleg21_3    92.75852
# 340             arteries_lleg19_0  221.768222
# 341             arteries_lleg28_1   66.908224
# 342             arteries_lleg23_0  141.467505
#
#                                   Radius Values End Condition
# 0                                  [12.5, 11.4]        [1, 2]
# 1                                  [11.4, 11.1]        [3, 4]
# 2                                        [7, 7]        [5, 6]
# 3                                  [11.1, 10.9]        [7, 8]
# 4      [2.0930494756709175, 1.7054911275342857]            ST
# ...

# %%
#Load in mirroring chart, left side only

mirroring_dict = np.loadtxt('MirroredVessels.txt')[:,0]

# %%
#For each location in mirroring chart (Left side) determine lrr as a function Rd
intial_guess = np.empty(0)

for vessel in mirroring_dict:
    Rd=vessel_df.iloc[int(vessel)]['Radius Values'][1]/10
    
    #DEBUG ATTEMPT
    #name = vessel_df.iloc[int(vessel)]['Name']
    #if 'kidney' in name: 
        #lrr_intial = 50
    if Rd > 0.025:
        lrr_intial = 10
    elif Rd <= 0.005:
        lrr_intial = 30
    else:
        lrr_intial = 20 
    
    intial_guess = np.append(intial_guess,lrr_intial)
print(intial_guess)
# Out:
# [10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 20. 20. 10. 20. 10. 20.]

# %%
#Write as a txt file
np.savetxt('intial_guess.txt',intial_guess)
