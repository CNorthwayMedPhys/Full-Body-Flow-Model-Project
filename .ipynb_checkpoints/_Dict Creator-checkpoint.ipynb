# %%
import pandas as pd
import numpy as np

# %%
#Load in the arterial map file
try:
    vessel_df = pd.read_pickle ('C:\\Users\\cbnor\\Documents\\Full Body Flow Model Project\\SysArteries.pkl')
except:
    vessel_df = pd.read_pickle ('C:\\Users\\Cassidy.Northway\\RemoteGit\\SysArteries.pkl')

# %%
#Note the index number of each segment which ends in a ST in a new array

filtered_df = vessel_df[vessel_df['End Condition'] == 'ST']
np_array = filtered_df.index.values
# Out:
#                               Name         lam  \
# 4     left_common_cartoid_artery_0  104.527284
# 6           right_carotid_artery_0  182.863106
# 14       left_vertebral_arteries_0  165.608679
# 16                    arteries29_0   39.228752
# 18                    arteries12_0  103.414497
# 20    superior_mesenteric_artery_0  122.922092
# 27                    arteries36_2   46.409265
# 28                     arteries8_0   23.719704
# 37                    arteries18_1   33.569981
# 40                    arteries10_0   154.23178
# 41                    arteries38_1   18.659046
# 44                arteries_lumb5_0   100.44517
# 48                    arteries50_0  118.637413
# 49         common_hepatic_artery_1   10.711196
# 51           left_gastric_artery_2   11.977538
# 52                     arteries3_0   49.091951
# 53                    arteries28_1    26.78368
# 54                    arteries34_0   29.901449
# 56                    arteries44_0  109.612058
# 58                     arteries6_0   20.299247
# 59                    arteries17_1   22.653211
# 60                    arteries22_0   11.655651
# 62                arteries_rarm7_0  150.367951
# 63                    arteries35_1   11.580522
# 64                    arteries48_0   33.948018
# 70            rkidney_arteries12_0   19.838719
# 71                splenic_artery_4    9.192449
# 72                    arteries49_0   21.016007
# 73                    arteries30_1    5.792033
# 76                arteries_larm5_0  142.137416
# 77                    arteries26_2   26.355267
# 78                    arteries20_0  153.070171
# 80                arteries_rarm4_0  107.684607
# 82                arteries_lumb4_0   58.487694
# 86             rkidney_arteries1_0    18.18393
# 88            rkidney_arteries11_0   19.279665
# 89             rkidney_arteries9_2   25.816755
# 91                    arteries32_1   17.072438
# 92                    arteries16_0   173.16756
# 94                arteries_larm9_0  103.804623
# 98                arteries_lumb2_0   95.178464
# 104           rkidney_arteries17_0   18.609809
# 105           rkidney_arteries13_2    8.261282
# 106            rkidney_arteries7_0   30.657848
# 108           rkidney_arteries16_0    43.94095
# 112               arteries_rarm8_0  163.523909
# 114              arteries_rarm13_0  149.978481
# 116               arteries_lumb0_0   57.506055
# 118           lkidney_arteries18_0   22.056941
# 120           lkidney_arteries13_0    19.01744
# 123            lkidney_arteries6_1   10.269828
# 124            lkidney_arteries9_0   16.496679
# 126            rkidney_arteries8_0   32.422965
# 127            rkidney_arteries5_2   27.301876
# 128           rkidney_arteries15_0    21.63775
# 130               arteries_larm7_0  164.405329
# 132              arteries_larm12_0  131.119871
# 133               arteries_rarm3_2   172.09371
# 134               arteries_rarm1_0  187.347573
# 138               arteries_lumb6_0   53.241964
# 140           lkidney_arteries14_0   19.128542
# 144           lkidney_arteries15_0   32.321777
# 145           lkidney_arteries20_1   18.964404
# 146            lkidney_arteries7_0   30.976572
# 149               arteries_larm6_2  126.890707
# 150               arteries_larm3_0  191.349018
# 154              arteries_rarm12_0  202.361728
# 155               arteries_rarm5_1  183.235153
# 160           lkidney_arteries11_0   17.574798
# 162            lkidney_arteries3_0    6.159685
# 163           lkidney_arteries10_1   12.287254
# 164            lkidney_arteries5_0   15.468684
# 165            lkidney_arteries4_4   21.072197
# 166            lkidney_arteries1_0   24.692687
# 167  right_superior_renal_artery_7   10.306839
# 168            rkidney_arteries4_0   33.709016
# 169            rkidney_arteries2_1   34.872986
# 170            rkidney_arteries3_0   15.758291
# 172               arteries_larm8_0   206.13545
# 173               arteries_larm1_1   140.60329
# 175               arteries_rarm2_4  125.203935
# 176               arteries_rarm6_0  171.165249
# 177               arteries_rarm0_1  199.848674
# 178              arteries_rarm11_0  244.642142
# 182           lkidney_arteries16_0    30.88613
# 184           lkidney_arteries17_0   22.808841
# 185            lkidney_arteries2_4   12.866901
# 186           lkidney_arteries22_0   18.175002
# 187              arteries_larm10_4  104.135281
# 188               arteries_larm0_0  160.010445
# 189              arteries_larm13_1   183.81922
# 190              arteries_larm11_0  255.672338
# 193   inferior_mesenteric_artery_1   82.933783
# 195   left_inferior_renal_artery_2   11.306461
# 196           lkidney_arteries19_0   17.988221
# 198           lkidney_arteries12_0   33.115655
# 200               arteries_lumb1_0   48.817086
# 202           rkidney_arteries10_0   30.737915
# 203            left_colic_artery_1    28.63381
# 204                sigmod_artery_0   27.581988
# 205   left_superior_renal_artery_8    8.831353
# 206            lkidney_arteries8_0   15.482512
# 208               arteries_lumb3_0   59.519697
# 209  right_inferior_renal_artery_2   19.110777
# 210           rkidney_arteries14_0   18.520281
# 220                   arteries43_0  295.936706
# 225                   arteries14_0   26.585746
# 226                   arteries15_0   73.150746
# 227                   arteries23_0    72.82054
# 229                   arteries19_0   93.152787
# 232  right_external_iliac_artery_3   36.116449
# 233                   arteries46_0   25.705146
# 234  right_internal_iliac_artery_1   22.443181
# 235                   arteries13_0   72.395472
# 237              arteries_rleg27_0   78.888445
# 241                   arteries39_0   42.727765
# 243              arteries_lleg26_0   80.550312
# 247              arteries_rleg30_0  111.509516
# 249               arteries_rleg0_0   67.932563
# 251               arteries_rleg3_0   24.190914
# 253                   arteries25_0   61.221164
# 255              arteries_lleg14_0  128.092313
# 257              arteries_lleg25_0  231.587032
# 259               arteries_lleg1_0   56.660067
# 261              arteries_rleg22_0   95.741865
# 263              arteries_rleg24_0   231.35766
# 265               arteries_rleg4_0   29.883772
# 266                   arteries47_0   51.318607
# 267                   arteries21_0   17.851486
# 269              arteries_lleg27_0   96.953507
# 271               arteries_lleg3_0   74.086605
# 273               arteries_lleg4_0   50.309951
# 275              arteries_rleg21_0  147.313733
# 279              arteries_rleg10_0   54.907156
# 281              arteries_lleg13_0  134.415999
# 285               arteries_lleg9_0   57.434676
# 288               arteries_rleg1_5   40.940025
# 289               arteries_rleg2_0   57.463545
# 290               arteries_rleg5_1   49.265432
# 291               arteries_rleg6_0   62.415859
# 292               arteries_rleg7_4   138.95315
# 293              arteries_rleg26_0  128.479308
# 296               arteries_lleg6_5   45.209203
# 297               arteries_lleg0_0   67.993314
# 298               arteries_lleg5_1   30.965757
# 299               arteries_lleg2_0   49.191846
# 300              arteries_lleg29_4  106.671091
# 301              arteries_lleg15_0  110.778565
# 302             right_leg_artery_7  146.790573
# 304              arteries_rleg23_1  160.235254
# 306              left_leg_artery_8  136.392783
# 308              arteries_lleg17_1  164.899961
# 310              arteries_rleg17_1  102.077601
# 311              arteries_rleg25_0  151.451626
# 314              arteries_lleg11_1   99.589922
# 315              arteries_lleg10_0  191.307614
# 316              arteries_lleg20_1  203.938227
# 318              arteries_rleg16_2   71.070415
# 319              arteries_rleg13_0   81.515307
# 326               arteries_rleg8_1  103.545138
# 327              arteries_rleg14_0  122.522698
# 330              arteries_lleg12_1  103.860267
# 331              arteries_lleg24_0  148.789236
# 332              arteries_rleg29_3   83.653913
# 333              arteries_rleg19_0  189.965728
# 334              arteries_rleg11_1   69.787602
# 335              arteries_rleg28_0  139.086316
# 337              arteries_lleg19_0  221.768222
# 338              arteries_lleg28_1   66.908224
# 339              arteries_lleg23_0  141.467505
# 340              arteries_lleg21_4   24.975392
# 341              arteries_lleg16_0   82.213622
#
#                                   Radius Values End Condition
# 4      [2.0930494756709175, 1.7054911275342857]            ST
# 6      [1.0372402320543708, 1.4077383015410248]            ST
# 14     [1.1904511587681472, 1.5347570064681884]            ST
# 16     [0.9744728655083622, 0.9741554501008665]            ST
# 18     [0.9366571695921398, 0.9173687812655963]            ST
# 20      [1.7587298532332765, 1.668764021716361]            ST
# 27     [1.0122563428183422, 1.0101608200417111]            ST
# 28     [1.0918864772638637, 1.0918462408172784]            ST
# 37     [0.7729202005173714, 0.7646014832108435]            ST
# 40     [0.5940294567610269, 0.5896636371048539]            ST
# 41     [0.8593499628668455, 0.8593833157144899]            ST
# 44     [0.6561615586482652, 0.6581225065019851]            ST
# 48     [1.0274548918648811, 0.9905103738663295]            ST
# 49     [1.7198291562694432, 1.7201667055837904]            ST
# 51     [1.1675379215033053, 1.1628559048659544]            ST
# 52     [0.5265069271667722, 0.5264183824221637]            ST
# 53     [0.9385049209531088, 0.9384988931666159]            ST
# 54     [0.6000833787044797, 0.6001062808669062]            ST
# 56     [0.7603399810863624, 0.7728536735337349]            ST
# 58      [1.0620789687934358, 1.061714379269768]            ST
# 59     [0.7819356030880923, 0.7814701551829157]            ST
# 60     [0.6493928640032148, 0.6494049339811503]            ST
# 62      [1.6769480459495787, 1.295796872840236]            ST
# 63     [0.5654264271700521, 0.5654292035129098]            ST
# 64    [0.35317410081616946, 0.3533525021196958]            ST
# 70       [1.0797273387815325, 1.07532982589257]            ST
# 71     [1.3468365157298807, 1.3469475377562303]            ST
# 72      [1.163588146028199, 1.1625611581024748]            ST
# 73        [1.24906891115633, 1.249083445127991]            ST
# 76      [1.7244286672964946, 1.457373008912477]            ST
# 77     [1.3631911142843929, 1.3622489742921995]            ST
# 78     [0.6251826248647133, 0.6259104893706171]            ST
# 80     [1.5174342422164837, 1.1818919949701296]            ST
# 82     [0.8941229925849569, 0.8937455847975245]            ST
# 86      [0.823606660563489, 0.8235918290166309]            ST
# 88      [0.8210238870808875, 0.821032471516316]            ST
# 89     [1.2322164002489684, 1.2147282440284637]            ST
# 91     [0.8842522085861171, 0.8843558462418053]            ST
# 92    [0.43275777293832485, 0.4330628863623082]            ST
# 94       [1.540918881405833, 1.310833785581163]            ST
# 98     [0.6191343139330482, 0.6201612195922495]            ST
# 104    [1.0144902888869256, 1.0139755051278014]            ST
# 105    [1.3299468175471103, 1.3266800033161605]            ST
# 106    [0.5287448851553891, 0.5287432231222275]            ST
# 108    [0.7853826419806444, 0.7577791137320492]            ST
# 112   [0.7701455454931968, 0.34386834156725643]            ST
# 114     [0.837719398574626, 0.7840808107483624]            ST
# 116    [0.9865255601356349, 0.9860769769957667]            ST
# 118    [1.4674541187031884, 0.7260217934254112]            ST
# 120    [1.3950812123301246, 0.6568367842934906]            ST
# 123     [0.7298821111390466, 0.577920362006816]            ST
# 124    [0.5740871382496042, 0.5396835175228778]            ST
# 126    [1.1598039133146811, 1.1369283282298281]            ST
# 127    [1.1587775993013867, 1.1325851576259243]            ST
# 128    [0.8112079451318674, 0.8109216181573107]            ST
# 130   [0.8060808529047836, 0.35032839171129365]            ST
# 132    [0.8647722234034264, 0.8546506549209344]            ST
# 133    [0.5454931154640105, 0.3315972816178415]            ST
# 134   [0.5851012476978436, 0.23313358192178085]            ST
# 138    [1.0575577253562052, 1.0570680032681425]            ST
# 140    [0.7333633980244303, 0.5801162971686824]            ST
# 144    [0.8437474323667391, 0.7250594627708115]            ST
# 145    [1.1263040169493792, 0.5839885688790818]            ST
# 146    [0.8003347979102367, 0.7416539144057186]            ST
# 149    [0.6925650029079378, 0.5576652803871868]            ST
# 150     [0.5479836185836771, 0.272030729677001]            ST
# 154   [0.7263566265949519, 0.24980647684094476]            ST
# 155    [0.7110180550558921, 0.4232662760655255]            ST
# 160    [0.8137766087962586, 0.8311630480531902]            ST
# 162    [0.9869374964315631, 0.9869373418784585]            ST
# 163    [1.0418657852300006, 0.7489650647245837]            ST
# 164     [0.6914113026637575, 0.642174485933598]            ST
# 165     [1.3553122651411424, 1.243413999259449]            ST
# 166    [1.0090186503480345, 0.9241911237081177]            ST
# 167    [1.5153035982435366, 1.5124791432722597]            ST
# 168    [0.5481364394605194, 0.5480692317317319]            ST
# 169    [0.7512771805508986, 0.7176942401858201]            ST
# 170    [0.9028454240564303, 0.9028514855565712]            ST
# 172    [0.6338308459862768, 0.2933229721857253]            ST
# 173    [0.8042822622246099, 0.5672535944085138]            ST
# 175    [0.8092976006351342, 0.6021822738884164]            ST
# 176  [0.45322027824438343, 0.19977608263782776]            ST
# 177   [0.5167443151473812, 0.37669443172533656]            ST
# 178     [0.393660541476849, 0.2674986791519483]            ST
# 182    [0.9767945162660525, 0.9359597550099688]            ST
# 184    [1.0891961240805763, 0.8850550143534965]            ST
# 185    [0.9355077561518153, 0.9187244552515876]            ST
# 186     [0.530511597430552, 0.5097609972781565]            ST
# 187    [0.8318584011569172, 0.6542381958037344]            ST
# 188    [0.4324711956417675, 0.2515404289567611]            ST
# 189    [0.5118973333703675, 0.3842902342254733]            ST
# 190  [0.38251034154004165, 0.29758120006798666]            ST
# 193    [1.4238001237692486, 1.4250433642555131]            ST
# 195    [0.9482135262750724, 0.8775024933531264]            ST
# 196    [0.5456098926227804, 0.5434740718685881]            ST
# 198    [0.6765613576958897, 0.4174923249461431]            ST
# 200    [1.0713020550107322, 1.0717875717586747]            ST
# 202    [0.7478518090418347, 0.7439774714382613]            ST
# 203    [0.9722081102530833, 0.9714453007228463]            ST
# 204     [0.927875164580459, 0.9262401420910893]            ST
# 205    [1.6049628418615658, 1.5811530210154707]            ST
# 206    [0.7426778078787258, 0.7231317464203516]            ST
# 208     [1.1648545372225962, 1.161471034921696]            ST
# 209    [1.2491918573266867, 1.2484101313523663]            ST
# 210    [1.0184318200191773, 1.0184324155473496]            ST
# 220   [0.4638794833079544, 0.46012702546947126]            ST
# 225    [0.9379967228022248, 0.9351440001717093]            ST
# 226    [0.7658548192461445, 0.7662970880766302]            ST
# 227     [1.202510388913491, 1.2031936188494274]            ST
# 229    [0.9001629588364272, 0.9009883490761122]            ST
# 232     [2.552653826111597, 2.2194570298841234]            ST
# 233     [0.9308123061012064, 0.932482728308435]            ST
# 234    [2.0545839511056583, 2.0605522428434893]            ST
# 235     [1.082827473484808, 1.0824779712365347]            ST
# 237      [1.229814315655308, 0.776395807727023]            ST
# 241     [0.610595841763823, 0.6084047133753993]            ST
# 243    [1.1747979526923815, 0.8664224766570109]            ST
# 247    [1.1680165031192453, 0.7480701991196965]            ST
# 249    [1.1383754660289354, 0.8191041598297524]            ST
# 251     [1.054696284280351, 0.5732802665019413]            ST
# 253    [0.9407189181381995, 0.9397488191243571]            ST
# 255    [0.9872056933300243, 0.9662850359959824]            ST
# 257    [1.8282908542415324, 0.7116237029770259]            ST
# 259    [0.6613185448670835, 0.6613294447583774]            ST
# 261    [1.1032088030111502, 0.5459311420945091]            ST
# 263    [1.7377634691882182, 0.5725238695322269]            ST
# 265   [0.9049747626283589, 0.39971352632675666]            ST
# 266    [0.8128624411420691, 0.8190334780786153]            ST
# 267    [1.0464243301722933, 1.0449710329119255]            ST
# 269    [1.0269951638748918, 0.7218511619032579]            ST
# 271     [1.072003975880322, 1.0490724450704318]            ST
# 273    [0.6392595838560985, 0.6392612693583706]            ST
# 275     [1.1081898196854976, 0.516239618941708]            ST
# 279  [0.41247900621433037, 0.39883184921575093]            ST
# 281     [1.254688524236303, 0.6685833439011799]            ST
# 285   [0.4277248690528284, 0.42765484125931597]            ST
# 288    [1.3273925206175414, 1.2214672075692914]            ST
# 289    [0.7264212297262528, 0.6874097044054807]            ST
# 290     [0.6775042253662289, 0.609360394722671]            ST
# 291    [0.2934486734575931, 0.2820383703221064]            ST
# 292    [0.4761375047966955, 0.3792675822478956]            ST
# 293   [0.2661442653040656, 0.25743462977629605]            ST
# 296    [1.2293696433643027, 1.2266248528035593]            ST
# 297    [0.6962096277854287, 0.6962312230481016]            ST
# 298    [0.9826121489116888, 0.9638981822625504]            ST
# 299   [0.3645502243631019, 0.36455048720006894]            ST
# 300    [0.6050391590743922, 0.5641048826790174]            ST
# 301    [0.2814749741499422, 0.2814667075644295]            ST
# 302    [0.8238101494348757, 0.4668520733896095]            ST
# 304     [0.8519442948811562, 0.552709987793035]            ST
# 306      [0.879407375243237, 0.527921144619179]            ST
# 308    [0.8499214742288966, 0.6428895184085403]            ST
# 310    [0.4930229112852293, 0.3399664763477952]            ST
# 311     [0.359969226245124, 0.2890975097095318]            ST
# 314  [0.46681913435602557, 0.31076777934817423]            ST
# 315   [0.28213527183131076, 0.2812283239620832]            ST
# 316    [0.6545979351595993, 0.6467051661178862]            ST
# 318    [0.6665993846009729, 0.6314724158556502]            ST
# 319   [0.6127522376556573, 0.39111315437495775]            ST
# 326   [0.31509426160680803, 0.2495366085205455]            ST
# 327   [0.3271346975131622, 0.21498349955960985]            ST
# 330   [0.3128888835552584, 0.24523905449551994]            ST
# 331   [0.2578068112496065, 0.20962157177623325]            ST
# 332   [0.26968178494025713, 0.2427521000774132]            ST
# 333   [0.2169075959619517, 0.11801695007428173]            ST
# 334     [0.363398442454153, 0.2582560393368188]            ST
# 335   [0.2755204774363098, 0.17351807117222803]            ST
# 337   [0.1801839607193014, 0.17067838755459327]            ST
# 338   [0.38420728718640085, 0.3226221270644884]            ST
# 339    [0.2761283849630335, 0.2399647470053623]            ST
# 340    [0.2747807166794465, 0.2745924622203466]            ST
# 341    [0.5805583135993121, 0.5307999903491233]            ST

# %%
#Create a second column with the matching segment numbers based on the matching map
empty_col = np.zeros((np.shape(np_array)[0],1))
array = np.append(np.expand_dims(np_array,axis=1),empty_col,axis=1)

#Read in the matching vessel names 
try:
    mirror_df = pd.read_excel ('C:\\Users\\cbnor\\Documents\\Full Body Flow Model Project\\Mirroring_Tuning_Map.xlsx', usecols ="B,C,E,F")
except:
    mirror_df = pd.read_excel ('C:\\Users\\Cassidy.Northway\\RemoteGit\\Mirroring_Tuning_Map.xlsx', usecols ="B,C,E,F")

left_vessels = mirror_df['Left Vessel'].reset_index()
right_vessels = mirror_df['Right Vessel'].dropna().reset_index()

#Search the vessel data frame to find string containing the vessel names, match to the index and update the second column
for i in range(0,len(right_vessels)):
    left_string = left_vessels['Left Vessel'].iloc[i]
    index_left = filtered_df[filtered_df['Name'].str.match(left_string+'_')].index.values

    right_string = right_vessels['Right Vessel'].iloc[i]
    index_right = filtered_df[filtered_df['Name'].str.match(right_string+'_')].index.values

    array_index = np.where(array[:,0] == index_left)
    array[array_index,1] = index_right
    
    #Remove the matched value rows
    rem_index = np.where(array[:,0] == index_right)
    array = np.delete(array,rem_index, axis = 0)

np.savetxt('MirroredVessels.txt',array)

# %%
#Load in ADAN vessel numbers
adan_df = mirror_df.dropna(subset=['Adan Vessels ID ']).reset_index()
display(adan_df)
# Out:
#                    Left Vessel                 Right Vessel  Adan Vessels ID   \
# 0               arteries_larm0               arteries_rarm6               NaN
# 1               arteries_larm1               arteries_rarm5               NaN
# 2               arteries_larm3               arteries_rarm1               NaN
# 3               arteries_larm5               arteries_rarm7               NaN
# 4               arteries_larm6               arteries_rarm3               NaN
# 5               arteries_larm7               arteries_rarm8               NaN
# 6               arteries_larm8              arteries_rarm12               NaN
# 7               arteries_larm9               arteries_rarm4               NaN
# 8              arteries_larm10               arteries_rarm2            1928.0
# 9              arteries_larm11              arteries_rarm11               NaN
# 10             arteries_larm12              arteries_rarm13               NaN
# 11             arteries_larm13               arteries_rarm0               NaN
# 12              arteries_lleg0               arteries_rleg2               NaN
# 13              arteries_lleg1               arteries_rleg3               NaN
# 14              arteries_lleg2               arteries_rleg6               NaN
# 15              arteries_lleg3               arteries_rleg0               NaN
# 16              arteries_lleg4               arteries_rleg4               NaN
# 17              arteries_lleg5               arteries_rleg5               NaN
# 18              arteries_lleg6               arteries_rleg1               NaN
# 19              arteries_lleg9              arteries_rleg10               NaN
# 20             arteries_lleg10              arteries_rleg25               NaN
# 21             arteries_lleg11              arteries_rleg17               NaN
# 22             arteries_lleg12               arteries_rleg8               NaN
# 23             arteries_lleg13              arteries_rleg21               NaN
# 24             arteries_lleg14              arteries_rleg30            2113.0
# 25             arteries_lleg15              arteries_rleg26               NaN
# 26             arteries_lleg16              arteries_rleg13               NaN
# 27             arteries_lleg17              arteries_rleg23               NaN
# 28             arteries_lleg19              arteries_rleg19               NaN
# 29             arteries_lleg20              arteries_rleg16               NaN
# 30             arteries_lleg21              arteries_rleg29               NaN
# 31             left_leg_artery             right_leg_artery               NaN
# 32             arteries_lleg23              arteries_rleg28               NaN
# 33             arteries_lleg24              arteries_rleg14               NaN
# 34             arteries_lleg25              arteries_rleg24            2450.0
# 35             arteries_lleg26              arteries_rleg27               NaN
# 36             arteries_lleg27              arteries_rleg22               NaN
# 37             arteries_lleg28              arteries_rleg11               NaN
# 38             arteries_lleg29               arteries_rleg7            2379.0
# 39              arteries_lumb0               arteries_lumb6               NaN
# 40              arteries_lumb3               arteries_lumb1               NaN
# 41              arteries_lumb2               arteries_lumb4               NaN
# 42                  arteries23  right_external_iliac_artery            2437.0
# 43                  arteries12                   arteries20               NaN
# 44                  arteries13                   arteries19               NaN
# 45                  arteries14                   arteries46               NaN
# 46                  arteries17                   arteries35               NaN
# 47                  arteries18                   arteries38               NaN
# 48                  arteries22                   arteries48               NaN
# 49        right_carotid_artery      left_vertebral_arteries            2512.0
# 50  superior_mesenteric_artery                          NaN             852.0
# 51  left_common_cartoid_artery                          NaN            2492.0
# 52  left_common_cartoid_artery                          NaN            2497.0
# 53  left_common_cartoid_artery                          NaN            2503.0
# 54       common_hepatic_artery                          NaN            2467.0
# 55  inferior_mesenteric_artery                          NaN            1031.0
#
#    Location
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8    _4,0.5
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24     0.25
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      0.5
# 35      NaN
# 36      NaN
# 37      NaN
# 38   _1, -1
# 39      NaN
# 40      NaN
# 41      NaN
# 42     0.25
# 43      NaN
# 44      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 49      0.5
# 50        0
# 51      0.5
# 52     0.75
# 53       -1
# 54    _0,-1
# 55    _0,-1
#     index                 Left Vessel                 Right Vessel  \
# 0       8             arteries_larm10               arteries_rarm2
# 1      24             arteries_lleg14              arteries_rleg30
# 2      34             arteries_lleg25              arteries_rleg24
# 3      38             arteries_lleg29               arteries_rleg7
# 4      42                  arteries23  right_external_iliac_artery
# 5      49        right_carotid_artery      left_vertebral_arteries
# 6      50  superior_mesenteric_artery                          NaN
# 7      51  left_common_cartoid_artery                          NaN
# 8      52  left_common_cartoid_artery                          NaN
# 9      53  left_common_cartoid_artery                          NaN
# 10     54       common_hepatic_artery                          NaN
# 11     55  inferior_mesenteric_artery                          NaN
#
#     Adan Vessels ID  Location
# 0             1928.0   _4,0.5
# 1             2113.0     0.25
# 2             2450.0      0.5
# 3             2379.0   _1, -1
# 4             2437.0     0.25
# 5             2512.0      0.5
# 6              852.0        0
# 7             2492.0      0.5
# 8             2497.0     0.75
# 9             2503.0       -1
# 10            2467.0    _0,-1
# 11            1031.0    _0,-1

# %%
left_vessels = adan_df['Left Vessel'].reset_index()
locations = adan_df['Location'].reset_index()

for i in range(0,len(left_vessels)):
    left_string = left_vessels['Left Vessel'].iloc[i]
    index_left = vessel_df[vessel_df['Name'].str.match(left_string+'_')]#.index.values
    location = locations['Location'].iloc[i]
    location = str(location)
    if "," in location:
        [location,length] = location.split(',')
        left_string = left_string + location
    else:
        left_string = index_left.iloc[0]['Name']
        length = location
    Adan_ID = adan_df.iloc[i]['Adan Vessels ID ']

#Now I need to find what the corresponding vessel
