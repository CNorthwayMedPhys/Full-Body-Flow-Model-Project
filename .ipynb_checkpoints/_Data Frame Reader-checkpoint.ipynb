# %%
import pandas as pd
import tkinter
from tkinter import filedialog
import numpy as np
tkinter.Tk().withdraw() # prevents an empty tkinter window from appearing
file_name = filedialog.askopenfilename()

df = pd.read_pickle(file_name)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
display(df)
#pd.reset_option('all')
# Out:
#                      Name        lam                            Radius Values  \
# 0  left_pulmonary_arts2_0  25.215123  [5.271518254792615, 1.2587711411256937]
#
#   End Condition
# 0            ST

# %%
df_cb = df['Name']
df_cb.to_clipboard(sep=',', index=False)

# %%
length = []


for i in range(0, np.shape(df)[0]):
    lam = df.at[i,'lam']
    Ru = df.at[i, 'Radius Values'][0]
    L = lam * Ru / 10
    length=np.append(length, L )

df.insert(2, "Length", length, True)

# %%
length_df = df.sort_values(by=['Length'])
display(df)
# Out:
#                      Name        lam     Length  \
# 0  left_pulmonary_arts2_0  25.215123  13.292198
#
#                              Radius Values End Condition
# 0  [5.271518254792615, 1.2587711411256937]            ST
