# %%
import pandas as pd
import tkinter
from tkinter import filedialog
import numpy as np
tkinter.Tk().withdraw() # prevents an empty tkinter window from appearing
file_name = filedialog.askopenfilename()

df = pd.read_pickle(file_name)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
display(df)
#pd.reset_option('all')
# Out:
#                    Name     Length End Condition
# 0          dias_aorta_0   7.504726        [1, 2]
# 1          dias_aorta_1   0.675013        [3, 4]
# 2          arteries11_0   6.720888        [5, 6]
# 3          dias_aorta_2   0.731291        [7, 8]
# 4           arteries2_0  21.878078            ST
# 5          arteries11_1  44.624413       [9, 10]
# 6          arteries37_0  18.967297            ST
# 7          dias_aorta_3   0.110126      [11, 12]
# 8          arteries41_0  19.714904            ST
# 9     arteries_rarm10_1   21.95004            ST
# 10     arteries_rarm2_0   2.966708      [13, 14]
# 11         dias_aorta_4  24.121654      [15, 16]
# 12          arteries5_0   3.786255       [17, 8]
# 13     arteries_rarm2_1  40.161626            ST
# 14    arteries_rarm13_0  12.563988            ST
# 15         dias_aorta_5    1.27815      [19, 20]
# 16          arteries0_0    1.18895      [21, 22]
# 17          arteries5_1  44.194015      [23, 24]
# 18         arteries41_0  19.714904            ST
# 19         dias_aorta_6   0.942314      [25, 26]
# 20          arteries1_0  21.618675            ST
# 21          arteries0_1   0.184477      [27, 28]
# 22         arteries42_0    5.64061            ST
# 23     arteries_larm2_1  25.212006            ST
# 24    arteries_larm10_0   2.717999      [29, 30]
# 25         dias_aorta_7   0.338908      [31, 32]
# 26  rkidney_arteries6_0  10.189378            ST
# 27          arteries0_2   10.03474            ST
# 28          arteries4_0   5.549735            ST
# 29    arteries_larm10_1  39.403293            ST
# 30    arteries_larm12_0  11.338882            ST
# 31         dias_aorta_8   6.309669      [33, 34]
# 32  lkidney_arteries0_0   8.648277            ST
# 33         dias_aorta_9   3.578662      [35, 36]
# 34         arteries24_0  15.536246            ST
# 35          arteries9_0   6.230391      [37, 38]
# 36         arteries27_0   6.415608      [39, 40]
# 37          arteries9_1   5.558768            ST
# 38    arteries_lleg22_0  66.709317      [41, 42]
# 39         arteries27_1  13.527127            ST
# 40    arteries_rleg18_0  11.958754      [43, 44]
# 41    arteries_lleg22_1  52.063313      [45, 46]
# 42    arteries_lleg17_0  53.100496            ST
# 43    arteries_rleg18_1   52.87848      [47, 48]
# 44     arteries_rleg1_0   9.612582            ST
# 45    arteries_lleg22_2  11.994482            ST
# 46    arteries_lleg11_0  11.210641            ST
# 47    arteries_rleg18_2   64.09709            ST
# 48    arteries_rleg23_0  53.245036            ST

# %%
length = []


for i in range(0, np.shape(df)[0]):
    lam = df.at[i,'lam']
    Ru = df.at[i, 'Radius Values'][0]
    L = lam * Ru / 10
    length=np.append(length, L )

df.insert(2, "Length", length, True)
# Out:
# Traceback (most recent call last):
#
#   File ~\WPy64-31241\python-3.12.4.amd64\Lib\site-packages\pandas\core\indexes\base.py:3805 in get_loc
#     return self._engine.get_loc(casted_key)
#
#   File index.pyx:167 in pandas._libs.index.IndexEngine.get_loc
#
#   File index.pyx:196 in pandas._libs.index.IndexEngine.get_loc
#
#   File pandas\\_libs\\hashtable_class_helper.pxi:7081 in pandas._libs.hashtable.PyObjectHashTable.get_item
#
#   File pandas\\_libs\\hashtable_class_helper.pxi:7089 in pandas._libs.hashtable.PyObjectHashTable.get_item
#
# KeyError: 'lam'
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#
#   Cell In[3], line 5
#     lam = df.at[i,'lam']
#
#   File ~\WPy64-31241\python-3.12.4.amd64\Lib\site-packages\pandas\core\indexing.py:2575 in __getitem__
#     return super().__getitem__(key)
#
#   File ~\WPy64-31241\python-3.12.4.amd64\Lib\site-packages\pandas\core\indexing.py:2527 in __getitem__
#     return self.obj._get_value(*key, takeable=self._takeable)
#
#   File ~\WPy64-31241\python-3.12.4.amd64\Lib\site-packages\pandas\core\frame.py:4214 in _get_value
#     series = self._get_item_cache(col)
#
#   File ~\WPy64-31241\python-3.12.4.amd64\Lib\site-packages\pandas\core\frame.py:4638 in _get_item_cache
#     loc = self.columns.get_loc(item)
#
#   File ~\WPy64-31241\python-3.12.4.amd64\Lib\site-packages\pandas\core\indexes\base.py:3812 in get_loc
#     raise KeyError(key) from err
#
# KeyError: 'lam'

# %%
length_df = df.sort_values(by=['Length'])
display(df)
